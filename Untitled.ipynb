# %%
import pandas as pd 
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt

# %% [markdown]
# 1. The brand wants to conduct a  basic analysis between features provided, with an objective of finding out if customer ratings across some categories/product types/price-ranges are having any consistent pattern. They also want to see if sales are dependent on some key information provided in description/prices/ratings etc.
#
# 2. Please conduct a basic analysis depicting any potential relationship of Ratings and Sales on any of the columns provided, and provide the python code along with outputs of the exploratory analysis/graphs along with comments

# %%
df1=pd.read_csv('cat_subcat.csv')
df1
# Out:
#                   category               sub_category
# 0                Baby Care           Baby Accessories
# 1                Baby Care        Baby Bath & Hygiene
# 2                Baby Care        Baby Food & Formula
# 3                Baby Care            Diapers & Wipes
# 4                Baby Care          Feeding & Nursing
# ..                     ...                        ...
# 85  Snacks & Branded Foods  Noodle, Pasta, Vermicelli
# 86  Snacks & Branded Foods          Pickles & Chutney
# 87  Snacks & Branded Foods        Ready To Cook & Eat
# 88  Snacks & Branded Foods           Snacks & Namkeen
# 89  Snacks & Branded Foods   Spreads, Sauces, Ketchup
#
# [90 rows x 2 columns]

# %%
df=pd.read_csv('retail products.csv')

# %%
df=pd.merge(df,df1,on='sub_category')

# %%
df
# Out:
#       index                                            product  \
# 0         1             Garlic Oil - Vegetarian Capsule 500 mg
# 1         9  Biotin & Collagen Volumizing Hair Shampoo + Bi...
# 2        21             Ceramic Barrel Brush - Colour May Vary
# 3        58                         Argan-Liquid Gold Hair Spa
# 4        65                 Aqua Halo Rejuvenating Conditioner
# ...     ...                                                ...
# 5410   3100  IQ+ Maternal Nutrition With DHA Health Drink -...
# 5411   3275                 Lady Bladder Control Pads - Normal
# 5412   2931                                     Pork - Chorizo
# 5413   3315                                      Buffalo Mince
# 5414   4213                      Chrysanthemum/Shevanti Flower
#
#                   sub_category                 brand  sale_price  \
# 0                    Hair Care     Sri Sri Ayurveda     248.6000
# 1                    Hair Care            StBotanica   1240.7400
# ...

# %%
df.isnull().sum()
# Out:
# index              0
# product            0
# sub_category       0
# brand              0
# sale_price         0
# market_price       0
# type               0
# rating          1710
# Quantity           0
# description       23
# category           0
# dtype: int64

# %% [markdown]
# ## Obseravations:
# 1. There are null values on rating and description, descriptions can be ignored but ratings are considered as valuable outcome need to look for an approach to fill these values.

# %%
df.shape
# Out:
# (5415, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5415 entries, 0 to 5414
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   index         5415 non-null   int64
#  1   product       5415 non-null   object
#  2   sub_category  5415 non-null   object
#  3   brand         5415 non-null   object
#  4   sale_price    5415 non-null   float64
#  5   market_price  5415 non-null   float64
#  6   type          5415 non-null   object
#  7   rating        3705 non-null   float64
#  8   Quantity      5415 non-null   int64
#  9   description   5392 non-null   object
#  10  category      5415 non-null   object
# dtypes: float64(3), int64(2), object(6)
# memory usage: 507.7+ KB

# %%
df.head()
# Out:
#    index                                            product sub_category  \
# 0      1             Garlic Oil - Vegetarian Capsule 500 mg    Hair Care
# 1      9  Biotin & Collagen Volumizing Hair Shampoo + Bi...    Hair Care
# 2     21             Ceramic Barrel Brush - Colour May Vary    Hair Care
# 3     58                         Argan-Liquid Gold Hair Spa    Hair Care
# 4     65                 Aqua Halo Rejuvenating Conditioner    Hair Care
#
#                   brand  sale_price  market_price                    type  \
# 0     Sri Sri Ayurveda     248.6000        248.60        Hair Oil & Serum
# 1            StBotanica   1240.7400       1240.74   Shampoo & Conditioner
# 2  Bronson Professional    593.2500        791.00     Tools & Accessories
# 3       Aroma Treasures    225.4350        237.30  Hair & Scalp Treatment
# 4               Azafran    190.6875        254.25   Shampoo & Conditioner
#
#    rating  Quantity                                        description  \
# ...

# %% [markdown]
# # Univariate Analysis

# %%
df['category'].value_counts()
# Out:
# Beauty & Hygiene            1558
# Gourmet & World Food         951
# Kitchen, Garden & Pets       701
# Foodgrains, Oil & Masala     551
# Snacks & Branded Foods       534
# Cleaning & Household         488
# Bakery, Cakes & Dairy        168
# Beverages                    145
# Baby Care                    121
# Fruits & Vegetables          114
# Eggs, Meat & Fish             84
# Name: category, dtype: int64

# %%
dfc=pd.DataFrame(df['category'].value_counts())
plt.pie(dfc['category'],labels=dfc.index,autopct='%0.1f%%')
plt.show()

# %% [markdown]
# ## Observations:
# ### Most selling products comes under these categories
# 1. Beauty & Hygiene
# 2. Gourmet & World Food
# 3. Kitchen, Garden & Pets
# 4. Foodgrains, Oil & Masala
# 5. Snacks & Branded Foods
# 6. Cleaning & Household

# %%
sns.histplot(data=df['market_price'],bins=3)
# Out:
# <AxesSubplot:xlabel='market_price', ylabel='Count'>

# %% [markdown]
# ## Observations:
# 1. Most of the products lie between price range of <=4000

# %% [markdown]
# # Bivariate Analysis

# %% [markdown]
# #### In this we are comparing sub categories of each category with the ratings, we can identify products having higher ratings.

# %%
for i in df['category'].unique():
    sns.stripplot(x=df[df['category']==i]['sub_category'],y=df[df['category']==i]['rating'])
    plt.xticks(rotation='vertical')
    plt.show()

# %% [markdown]
# ## Observations:
#
# 1. these products have top ratings
# 2. these products have ratings not less than 3
# 3. these products have less sales etc

# %%
df.head()
# Out:
#    index                                            product sub_category  \
# 0      1             Garlic Oil - Vegetarian Capsule 500 mg    Hair Care
# 1      9  Biotin & Collagen Volumizing Hair Shampoo + Bi...    Hair Care
# 2     21             Ceramic Barrel Brush - Colour May Vary    Hair Care
# 3     58                         Argan-Liquid Gold Hair Spa    Hair Care
# 4     65                 Aqua Halo Rejuvenating Conditioner    Hair Care
#
#                   brand  sale_price  market_price                    type  \
# 0     Sri Sri Ayurveda     248.6000        248.60        Hair Oil & Serum
# 1            StBotanica   1240.7400       1240.74   Shampoo & Conditioner
# 2  Bronson Professional    593.2500        791.00     Tools & Accessories
# 3       Aroma Treasures    225.4350        237.30  Hair & Scalp Treatment
# 4               Azafran    190.6875        254.25   Shampoo & Conditioner
#
#    rating  Quantity                                        description  \
# ...

# %%
plt.scatter(df['market_price'],df['rating'],s=df['rating']/1.5)
plt.xlabel('market_price')
plt.ylabel('rating_score')
plt.show()

# %% [markdown]
# ## Observations:
# 1. market price does not have any considerable impact on ratings.

# %%
plt.scatter(df['market_price'],df['Quantity'],color='red',marker='+')
plt.show()

# %% [markdown]
# ## Observations:
# 1. Sales Quantity does not have impact of market price.

# %%
df.head()
# Out:
#    index                                            product sub_category  \
# 0      1             Garlic Oil - Vegetarian Capsule 500 mg    Hair Care
# 1      9  Biotin & Collagen Volumizing Hair Shampoo + Bi...    Hair Care
# 2     21             Ceramic Barrel Brush - Colour May Vary    Hair Care
# 3     58                         Argan-Liquid Gold Hair Spa    Hair Care
# 4     65                 Aqua Halo Rejuvenating Conditioner    Hair Care
#
#                   brand  sale_price  market_price                    type  \
# 0     Sri Sri Ayurveda     248.6000        248.60        Hair Oil & Serum
# 1            StBotanica   1240.7400       1240.74   Shampoo & Conditioner
# 2  Bronson Professional    593.2500        791.00     Tools & Accessories
# 3       Aroma Treasures    225.4350        237.30  Hair & Scalp Treatment
# 4               Azafran    190.6875        254.25   Shampoo & Conditioner
#
#    rating  Quantity                                        description  \
# ...

# %%
df['sub_category'].unique()
# Out:
# array(['Hair Care', 'Storage & Accessories', 'Pooja Needs',
#        'Bins & Bathroom Ware', 'Bath & Hand Wash', 'All Purpose Cleaners',
#        'Skin Care', 'Mops, Brushes & Scrubs', 'Cooking & Baking Needs',
#        'Chocolates & Biscuits', 'Fresheners & Repellents',
#        'Snacks, Dry Fruits, Nuts', 'Dairy & Cheese',
#        'Pasta, Soup & Noodles', 'Dry Fruits', 'Drinks & Beverages',
#        'Kitchen Accessories', 'Flask & Casserole', 'Breakfast Cereals',
#        'Frozen Veggies & Snacks', 'Fruit Juices & Drinks',
#        'Cookies, Rusk & Khari', 'Fragrances & Deos', 'Tea',
#        'Masalas & Spices', "Men's Grooming", 'Chocolates & Candies',
#        'Steel Utensils', 'Tinned & Processed Food', 'Organic Staples',
#        'Sauces, Spreads & Dips', 'Pickles & Chutney',
#        'Ready To Cook & Eat', 'Baby Bath & Hygiene', 'Stationery',
#        'Pet Food & Accessories', 'Biscuits & Cookies', 'Oral Care',
# ...

# %%
plt.figure(figsize=(24,6))
sns.barplot(x=df['sub_category'],y=df['Quantity'])
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# ## Observations:
# 1. highest sales: ---------------
# 2. lowest sales:  ---------------
# 3. Moderate sales:---------------
